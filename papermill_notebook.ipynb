# %%
import papermill as pm

pm.execute_notebook(
    'report_notebook.ipynb', # 실행할 노트북
    'report_notebook_output.ipynb', # Output 노트북 저장, 파라미터로 필요해서 필요없어도 지정해야함
     parameters = dict(ENVIRONMENT='local') # 파라미터 dict형태로 주입, 첫 번째 태그의 셀만 파라미터 주입됨
)
# Out:
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'markdown',
#    'id': 'f8c00481',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-08-10T04:16:12.190958',
#      'end_time': '2022-08-10T04:16:12.217597',
#      'duration': 0.026639,
#      'status': 'completed'}},
#    'source': "### Pymongo\n- /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip\n- pip install pymongo\n\n### AWS boto3 + Papermill\n- ! pip3 install 'papermill[s3]\n\n### 동작 되고 있는지 로깅 필요"},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'id': '50d54bcc',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2022-08-10T04:16:12.225751',
#      'end_time': '2022-08-10T04:16:12.238759',
#      'duration': 0.013008,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2022-08-10T04:16:12.232204Z',
# ...

# %%
# 컨테이너에서는 CLI로 수행
!  papermill papermill_vos.ipynb papermill_vos_output.ipynb -p title '2022-08-10-Wed' -p x 123456
# Out:
# Input Notebook:  papermill_vos.ipynb
# Output Notebook: papermill_vos_output.ipynb
# Generating grammar tables from /Users/user/Library/Python/3.8/lib/python/site-packages/blib2to3/Grammar.txt
# Writing grammar tables to /Users/user/Library/Caches/black/22.1.0/Grammar3.8.9.final.0.pickle
# Writing failed: [Errno 2] No such file or directory: '/Users/user/Library/Caches/black/22.1.0/tmpw0w7p0yq'
# Generating grammar tables from /Users/user/Library/Python/3.8/lib/python/site-packages/blib2to3/PatternGrammar.txt
# Writing grammar tables to /Users/user/Library/Caches/black/22.1.0/PatternGrammar3.8.9.final.0.pickle
# Writing failed: [Errno 2] No such file or directory: '/Users/user/Library/Caches/black/22.1.0/tmpz3wfndws'
# ...
# Executing: 100%|██████████████████████████████| 13/13 [00:02<00:00,  5.71cell/s]
